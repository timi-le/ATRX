# %% [markdown]
# # FX Quant Trading System - Model Training
# This notebook uses a dedicated Python script to train our models on Colab.

# %%
import os

REPO_URL = "https://github.com/timi-le/ATRX.git"
PROJECT_DIR = "/content/ATRX"

if os.path.exists(PROJECT_DIR):
    print("Repository already cloned. Pulling latest changes...")
    os.chdir(PROJECT_DIR)
    # !git pull
else:
    print("Cloning repository...")
    # !git clone {REPO_URL} {PROJECT_DIR}
    os.chdir(PROJECT_DIR)

print("Current directory:", os.getcwd())

# %%
print("Installing dependencies from requirements.txt...")
# !pip install -r requirements.txt

print("\nInstalling additional libraries for Colab...")
# !pip install ta-lib-binary

print("\nDependency installation complete.")

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

models_dir = '/content/drive/MyDrive/FX_Models'
os.makedirs(models_dir, exist_ok=True)
print(f"Google Drive mounted. Models will be saved to: {models_dir}")

# %%
print("Executing the training script...")
# !python scripts/colab_training.py

# %%
models_dir = '/content/drive/MyDrive/FX_Models'
print(f"Listing files in Google Drive target directory: {models_dir}")
# !ls -lh {models_dir}
